# %% [markdown]
# # Feature construction for carrier-mobility modeling
#
# This notebook creates the 240 composition/temperature descriptors used by the
# machine-learning workflow. The repetitive feature-engineering code from the
# original notebook has been moved to `src/features.py`.
#
# **Reproducibility note:** the aggregation definitions are intentionally kept
# consistent with the original research code. See `VALIDATION_NOTES.md` before
# changing any scientific formula.

# %%
from pathlib import Path
import sys

PROJECT_ROOT = Path.cwd().resolve().parent if Path.cwd().name == "notebooks" else Path.cwd().resolve()
sys.path.insert(0, str(PROJECT_ROOT))
from src.features import run_feature_pipeline

# %%
INPUT_CSV = PROJECT_ROOT / "data" / "Electricity_complete.csv"
OUTPUT_DIR = PROJECT_ROOT / "data" / "processed"

outputs = run_feature_pipeline(INPUT_CSV, OUTPUT_DIR)
outputs

# %% [markdown]
# The pipeline writes:
#
# - `N_type_carrier.csv`
# - `Elem_Features.csv`
# - `FVectors_data.csv`
# - `FVectors_MMS.csv`
# - `FVectors_SDS.csv`
#
# The model notebook uses `FVectors_MMS.csv` and `N_type_carrier.csv`.
